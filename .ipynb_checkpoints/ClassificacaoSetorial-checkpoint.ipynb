# %% [markdown]
# #

# %% [markdown]
# # <center>Web Scraping

# %% [markdown]
# ___

# %%
# Imports
import re
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "" --iversions
# Out:
# requests: 2.27.1
# re      : 2.2.1
# pandas  : 1.2.2
# json    : 2.0.9

# %%
# Scraping
import re
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# ___

# %%
url = 'https://www.ivalor.com.br/empresas/listagem?p={}'
pages = list(range(1,30,1))

# %%
def scrapSectorsTable():
    
    lista_linhas = []
    
    for page in pages:

        # Return HTML
        resposta = requests.get(url.format(page), headers={'User-Agent': 'Custom'})
        bruto = BeautifulSoup(resposta.text, 'html.parser')

        # Filters
        dados_brutos = bruto.find('tbody', id = 'tab_empresas_body')
        linhas = dados_brutos.find_all('tr')
        
        for linha in linhas:
            cells = linha.find_all('td')
            str_cells = str(cells)
            clean1 = re.compile('<.*?>')
            clean = re.sub(clean1, '', str_cells)
            clean = re.sub(r'\xa0', '', clean)
            clean = re.sub(r"^\s+" , "" , clean)
            clean = re.sub(r'\[', '', clean)
            clean = re.sub(r'\]', '', clean)
            
            lista_linhas.append(clean)
            
    # Create dataframe
    df = pd.DataFrame(lista_linhas)
        
    # Expand string
    df1 = df[0].str.split(',', expand = True)
        
    # Extract labels
    col_labels = bruto.find_all('th')
    all_header = []
    col_str = str(col_labels)
    cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
    all_header.append(cleantext2)
    df_head = pd.DataFrame(all_header)
    df_head1 = df_head[0].str.split(',', expand = True)
    
    # More cleaning
    df_head1[0] = df_head1[0].str.strip('[')
    df_head1[9] = df_head1[9].str.strip(']')

        
    # Concat dataframe 
    df_full = pd.concat([df_head1, df1]).reset_index(drop = True)
    
    # Concat dataframe 
    df_full = pd.concat([df_head1, df1]).reset_index(drop = True)
    df_full = df_full.rename(columns = df_full.iloc[0]).drop(df_full.index[[0]])
    df_full['Investing'] = '-'
    
    # More cleaning
    df_full.columns = df_full.columns.str.strip(' ')
    for col in df_full.columns.to_list():
        df_full[col] = [x.strip(' ') for x in df_full[col]]
        
    return df_full

# %%
df_sectors = scrapSectorsTable().iloc[:,2:]

# %%
df_sectors = df_sectors.loc[df_sectors['Ações'] != 'HYPE3']

# %%
# df mega cap
mega_cap = df_sectors.loc[df_sectors['Classificação'].isin(['Mega Cap'])].groupby(['Classificação', 
                                                                                   'Setor', 'Subsetor', 'Segmento',
                                                                                   'Empresa', 'Ações']).sum().reset_index()

# add link mega-cap
count = 0
link_investing = ['ambev-pn', 'bradesco-pn-n1',  'itauunibanco-pn-edj-n1', 'vale-on-n1', 'petrobras-pn']
for company in mega_cap['Empresa']:
    df_sectors.loc[df_sectors['Empresa'] == company, 'Investing'] = link_investing[count]
    count +=1

# %%
df_sectors.loc[df_sectors['Investing'] != '-']
# Out:
#           Empresa         Ações Classificação  \
# 3       AMBEV S/A         ABEV3      Mega Cap
# 40       BRADESCO  BBDC3  BBDC4      Mega Cap
# 216  ITAUUNIBANCO  ITUB3  ITUB4      Mega Cap
# 308     PETROBRAS  PETR3  PETR4      Mega Cap
# 408          VALE         VALE3      Mega Cap
#
#                               Listagem                Tag Along  \
# 3              Balcão Org. Tradicional        80% para ações ON
# 40   Nível 1 de Governança Corporativa        80% para ações ON
# 216  Nível 1 de Governança Corporativa        80% para ações ON
# 308  Nível 2 de Governança Corporativa  100% para ações ON e PN
# 408                       Novo Mercado       100% para ações ON
#
#                                Setor                         Subsetor  \
# 3                Consumo não Cíclico                          Bebidas
# 40                        Financeiro       Intermediários Financeiros
# 216                       Financeiro       Intermediários Financeiros
# ...

# %%
# df big cap
big_cap = df_sectors.loc[df_sectors['Classificação'].isin(['Big Cap'])].groupby(['Classificação', 
                                                                       'Setor', 'Subsetor', 'Segmento',
                                                                       'Empresa', 'Ações']).sum().reset_index()


# add link big-cap
count = 0
link_investing = ['weg-on-ej-nm', 'ccr-sa-on-nm', 'all-amer-lat-on-nm', 'telef-brasil-on', 'tim-part-s-a-on-nm', 
                  'magaz-luiza-on-nm', 'lojas-renner-on-nm', 'localiza-on-ej-nm', 'jbs-on-nm', 'atacadao-sa',
                  'brasil-on', 'banco-btg-pactual-sa' , 'itausa-pn-ej-n1', 'santander-br-unt-ed-n2', 'bbseguridad',
                  'caixa-seguridade-participacoes', 'bmfbovespa-on-nm', '-', 'suzano-papel-celulose', 'braskem-pna-n1',
                  'gerdau-pn-n1', 'cosan-on-nm', 'raiadrogasil-on-nm', 'hapvida-participacoes-investimentos',
                  '-', 'rede-dor-sao-luiz', 'cemig-pn-n1', 'copel-on', 'cpfl-energia-on-nm', 'eletrobras-on', 'tractebel-on-nm',
                  'equatorial-on-nm', 'sabesp-on'] #'hypermarcas-sa?cid=18698', 

for company in big_cap['Empresa']:
    df_sectors.loc[df_sectors['Empresa'] == company, 'Investing'] = link_investing[count]
    count +=1

# %%
# Mid cap

# %%
# small_cap

# %%
# df to filter companies to scraper
df_investing = df_sectors.loc[df_sectors['Investing'] != '-'].reset_index(drop = True)

# %%
df_singleScrap = df_investing[['Empresa', 'Investing']].drop_duplicates().reset_index(drop = True)

# %%
df_investing
# Out:
#          Empresa                        Ações Classificação  \
# 0      AMBEV S/A                        ABEV3      Mega Cap
# 1          ASSAI                        ASAI3       Big Cap
# 2         BRASIL                        BBAS3       Big Cap
# 3       BRADESCO                 BBDC3  BBDC4      Mega Cap
# 4   BBSEGURIDADE                        BBSE3       Big Cap
# 5     BTGP BANCO         BPAC11  BPAC3  BPAC5       Big Cap
# 6         CCR SA                        CCRO3       Big Cap
# 7          CEMIG                 CMIG3  CMIG4       Big Cap
# 8   CPFL ENERGIA                        CPFE3       Big Cap
# 9          COPEL  CPLE11  CPLE3  CPLE5  CPLE6       Big Cap
# 10  CARREFOUR BR                        CRFB3       Big Cap
# 11         COSAN                        CSAN3       Big Cap
# 12  CAIXA SEGURI                        CXSE3       Big Cap
# 13  ENGIE BRASIL                        EGIE3       Big Cap
# 14    ELETROBRAS          ELET3  ELET5  ELET6       Big Cap
# ...

# %%
df_investing.to_csv('df_investing.csv', index = False)

# %% [markdown]
# ___
